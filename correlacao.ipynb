# %% [markdown]
# <a href="https://colab.research.google.com/github/wellalb/Data-Science/blob/main/correlacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fonte: Wikimedia Commons - Licença CC
#
# ![image.png](data:image/png;base64,...)
#
# As queimadas são um problema global, que podem afetar populações inteiras, inclusive alterando fatores climáticos importantes no mundo. Analise o dataset forestfires.csv , que é um conjunto de dados que contém fatores que podem levar a incêndios florestais no nordeste de Portugal. O dataset iInclui fatores climáticos e variáveis categóricas, como dias da semana. Contém 13 variáveis e  517 observações diárias. Para este exercício, porém, considere apenas as variáveis wind (velocidade do vento em km/h), temp (temperatura em Celsius) e area (área, em km2, afetada pela queimada).
#
# O formato .csv é um formato de representação de dados em texto bastante popular na área de Ciência de Dados. Todas as planilhas de cálculo têm mecanismos para importar arquivos csv. Para o Excel, por eemplo, veja neste link.
#
# Sobre este dataset, analise as seguintes afirmativas:
#
# A correlação entre wind e area é muito próxima de 0, podendo ser dito que praticamente não há correlação
# A correlação entre temp e area é fraca, positiva
# A correlação entre temp e wind é fraca, negativa
# Assinale a alternativa que contém todas as afirmativas corretas, e apenas elas.

# %%
# library import

import pandas as pd
import seaborn as sn

# %%
# leitura dos dados

data = pd.read_csv("https://raw.githubusercontent.com/wellalb/Data-Science/main/forestfires.csv")
print(data)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %%
# análise de correlação

correlation = data.corr()

# %%
# plot da matriz de correlação

plot = sn.heatmap(correlation, annot = True, fmt=".1f", linewidths=.6)
plot

# %% [markdown]
# Dicas:
# Como podemos interpretar os valores que ρ pode assumir?
#
# ρ = 0,9 a 1 (positivo ou negativo): correlação muito forte;
#
# ρ = 0,7 a 09 (positivo ou negativo): correlação forte;
#
# ρ = 0,5 a 0,7 (positivo ou negativo): correlação moderada;
#
# ρ = 0,3 a 0,5 (positivo ou negativo): correlação fraca;
# # Nova seção
# ρ = 0 a 0,3 (positivo ou negativo): não possui correlação.
#
# Assinale a alternativa que contém todas as afirmativas corretas, e apenas elas.
# Sobre este dataset, analise as seguintes afirmativas:
#
# I - A correlação entre wind e area é muito próxima de 0, podendo ser dito que praticamente não há correlação
# II - A correlação entre temp e area é fraca, positiva
# III - A correlação entre temp e wind é fraca, negativa
#
# ( )Nenhuma está correta
#
#
# ( )Apenas a III
#
#
# ( )Todas estão corretas
#
#
# ( )II e III
#
#
# ( )Apenas a I
